# %%
# %cd ../
# Out:
# /home/zulqarnain/Code/htfa_rewrite_batching/htfatorch

# %%
import logging
import numpy as np
import htfa_torch.dtfa as DTFA
import htfa_torch.niidb as niidb
import htfa_torch.tardb as tardb
import htfa_torch.utils as utils

# %%
# %matplotlib inline

# %%
logging.basicConfig(format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %H:%M:%S',
                    level=logging.INFO)

# %%
affvids_db = tardb.FmriTarDataset('data/affvids2018_mc_zrest_norest.tar')

# %%
dtfa = DTFA.DeepTFA(affvids_db, num_factors=100, embedding_dim=2)

# %%
def task_labeler(task):
    if 'heights' in task:
        return 'Heights'
    elif 'social' in task:
        return 'Social threat'
    elif 'spider' in task:
        return 'Spiders'
    elif 'rest' in task:
        return 'Rest'
    else:
        return None

def rest_task_labeler(task):
    if task == 'rest':
        return 'Rest'
    else:
        return 'Task'

# %%
dtfa.load_state('data/affvids_n2000_k100_07262021_223134')

# %%
dtfa.scatter_task_embedding(labeler=task_labeler, figsize=None, colormap='Set1',
                            filename='affvids_norest_task_embedding.pdf')
# Out:
# /home/zulqarnain/Code/htfa_rewrite_batching/htfatorch/htfa_torch/utils.py:153: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dtfa.load_state('data/affvids_n2000_k100_07272021_153727')

# %%
dtfa.scatter_task_embedding(labeler=task_labeler, figsize=None, colormap='Set1',
                            filename='affvids_norest_task_embedding.pdf')
# Out:
# /home/zulqarnain/Code/htfa_rewrite_batching/htfatorch/htfa_torch/utils.py:153: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dtfa.load_state('data/affvids_n2000_k100_07272021_231350')

# %%
dtfa.scatter_task_embedding(labeler=task_labeler, figsize=None, colormap='Set1',
                            filename='affvids_norest_task_embedding.pdf')
# Out:
# /home/zulqarnain/Code/htfa_rewrite_batching/htfatorch/htfa_torch/utils.py:153: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dtfa.load_state('data/affvids_n2000_k100_07282021_163156')

# %%
dtfa.scatter_task_embedding(labeler=task_labeler, figsize=None, colormap='Set1',
                            filename='affvids_norest_task_embedding.pdf')
# Out:
# /home/zulqarnain/Code/htfa_rewrite_batching/htfatorch/htfa_torch/utils.py:153: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dtfa.load_state('data/affvids_n2000_k100_07282021_234935')

# %%
dtfa.scatter_task_embedding(labeler=task_labeler, figsize=None, colormap='Set1',
                            filename='affvids_norest_task_embedding.pdf')
# Out:
# /home/zulqarnain/Code/htfa_rewrite_batching/htfatorch/htfa_torch/utils.py:153: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
